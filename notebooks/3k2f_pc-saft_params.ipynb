# %% [markdown]
# # Guessing the Parameters for a PC-SAFT Model of 3k2f Polyol
#
# Begun July 22, 2021 to produce plots for ICTAM 2020+1.
#
# Only plots "official" results (in csv labeled `3k2f_<T>c.csv` in dft sensitivity folders).

# %%
# %load_ext autoreload
# %autoreload 2

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import dataproc
import plot

from importlib import reload

# System parameters
# molecular weight of CO2
mw_co2 = 44.01
# conversion of m3 per mL
m3_per_mL = 1E-6
# Save plots?
save_plots = True
# file path to saved data
data_folder = '../g-adsa_results/'
# csv data files
csv_file_list = ['3k2f_31c', '3k2f_60c_lop', '3k2f_60c_hip']

# %% [markdown]
# Loads data into dictionary.

# %%
d = dataproc.load_proc_data(csv_file_list, data_folder)

# %% [markdown]
# Compare results of prediction with guessed PC-SAFT parameters to actual data.

# %% [markdown]
# ### Solubility

# %%
from importlib import reload
reload(dataproc)

# plot parameters
ax_fs = 18
tk_fs = 14


# just for the label--doesn't affect the plot
epsn = 228.5

# folder of csv data files showing sensitivity of DFT predictions to PC-SAFT parameters
dft_sensitivity_folder = 'dft_pred//3k2f_31c_sensitivity//'

# loads dft predictions into a similarly structured dictionary
d_dft = dataproc.load_dft(dft_sensitivity_folder)

fig = plt.figure(figsize=(12, 4))
ax = fig.add_subplot(111)
# plots interfacial tension for 30 C
ax = plot.sensitivity_manual(d, d_dft, '3k2f_31c', 'solub', 'epsn', epsn, data_folder, '', ['epsn_228-5~sigma_3-01~N_144-0', ''],
                                color='#1181B3', ms=10, m_ads='o', m_des='o', lw=4, ax=ax)



# folder of csv data files showing sensitivity of DFT predictions to PC-SAFT parameters
dft_sensitivity_folder = 'dft_pred//3k2f_60c_sensitivity//'

# loads dft predictions into a similarly structured dictionary
d_dft = dataproc.load_dft(dft_sensitivity_folder)

ax = plot.sensitivity_manual(d, d_dft, '3k2f_60c_lop', 'solub', 'epsn', epsn, data_folder, '', [],
                                color='#B74A0D', ms=10, m_ads='o', m_des='o', lw=4, ax=ax)
ax.tick_params(labelsize=tk_fs)
ax.set_title('')
ax.set_xlabel(ax.xaxis.get_label().get_text(), fontsize=ax_fs)
ax.set_ylabel(ax.yaxis.get_label().get_text(), fontsize=ax_fs)
# Out:
# Analyzing dft_pred//3k2f_31c_sensitivity\3k2f_31c.csv
# Analyzing dft_pred//3k2f_31c_sensitivity\3k2f_31c_obsolete.csv
# No co2 density in dft_pred//3k2f_31c_sensitivity\3k2f_31c_obsolete.csv.
# Analyzing dft_pred//3k2f_31c_sensitivity\epsn_217-0.csv
# Analyzing dft_pred//3k2f_31c_sensitivity\epsn_224-0.csv
# Analyzing dft_pred//3k2f_31c_sensitivity\epsn_224-0~sigma_3-00.csv
# Analyzing dft_pred//3k2f_31c_sensitivity\epsn_224-0~sigma_3-07.csv
# Analyzing dft_pred//3k2f_31c_sensitivity\epsn_228-5~sigma_3-01~N_144-0.csv
# Analyzing dft_pred//3k2f_31c_sensitivity\epsn_232-8~sigma_3-22.csv
# Analyzing dft_pred//3k2f_31c_sensitivity\epsn_240-0.csv
# Analyzing dft_pred//3k2f_31c_sensitivity\epsn_240-0~sigma_3-07.csv
# Analyzing dft_pred//3k2f_31c_sensitivity\epsn_258-0~sigma_3-17.csv
# Analyzing dft_pred//3k2f_31c_sensitivity\N_117-0.csv
# Analyzing dft_pred//3k2f_31c_sensitivity\N_129-0.csv
# Analyzing dft_pred//3k2f_31c_sensitivity\sigma_2-86.csv
# Analyzing dft_pred//3k2f_31c_sensitivity\sigma_3-07.csv
# Analyzing dft_pred//3k2f_31c_sensitivity\sigma_3-16.csv
# Analyzing dft_pred//3k2f_31c_sensitivity\T_303-75.csv
# Analyzing dft_pred//3k2f_31c_sensitivity\T_304-75.csv
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-19-7d72af179a85> in <module>
#      20 # plots interfacial tension for 30 C
#      21 ax = plot.sensitivity_manual(d, d_dft, '3k2f_31c', 'solub', 'epsn', epsn, data_folder, '', ['epsn_228-5~sigma_3-01~N_144-0', 'sigma_3-01'],
# ---> 22                                 color='#1181B3', ms=10, m_ads='o', m_des='o', lw=4, ax=ax)
#      23
#      24
#
# ~\OneDrive - California Institute of Technology\Documents\Research\Kornfield\ANALYSIS\g-adsa\plot.py in sensitivity_manual(d, d_dft, tag_meas, prop, param_varied, param_fit_val, data_folder, fig_name, tags_2_plot, solub, cmap_max, cmap_type, param_split_char, ax, val_split_char, dec_pt_char, color, ms, m_ads, m_des, lw)
#     462         tag_lgd, color = tag_lgd_color
#     463         tag, lgd = tag_lgd
# --> 464         ax.plot(d_dft[tag][x], d_dft[tag][prop], color=color, label=lgd, lw=lw)
#     465
#     466     # puts legend outside of plot box
#
# KeyError: 'sigma_3-01'

# %% [markdown]
# ### Interfacial Tension

# %%
reload(dataproc)
reload(plot)

ax_fs = 20
tk_fs = 18

# folder of csv data files showing sensitivity of DFT predictions to PC-SAFT parameters
dft_sensitivity_folder = 'dft_pred//3k2f_31c_sensitivity//'

# loads dft predictions into a similarly structured dictionary
d_dft = dataproc.load_dft(dft_sensitivity_folder)

fig = plt.figure(figsize=(12, 4))
ax = fig.add_subplot(111)
# plots interfacial tension for 30 C
ax = plot.sensitivity_manual(d, d_dft, '3k2f_31c', 'if_tension', 'epsn', epsn, data_folder, '', ['epsn_228-5~sigma_3-01~N_144-0'],
                                color='#1181B3', ms=10, m_ads='o', m_des='o', lw=4, ax=ax)
# folder of csv data files showing sensitivity of DFT predictions to PC-SAFT parameters
dft_sensitivity_folder = 'dft_pred//3k2f_60c_sensitivity//'

# loads dft predictions into a similarly structured dictionary
d_dft = dataproc.load_dft(dft_sensitivity_folder)

ax = plot.sensitivity_manual(d, d_dft, '3k2f_60c_lop', 'if_tension', 'epsn', epsn, data_folder, '', [],
                                color='#B74A0D', ms=10, m_ads='o', m_des='o', lw=4, ax=ax)
ax.tick_params(labelsize=tk_fs)
ax.set_title('')
ax.set_xlabel(ax.xaxis.get_label().get_text(), fontsize=ax_fs)
ax.set_ylabel(ax.yaxis.get_label().get_text(), fontsize=ax_fs)
# Out:
# Analyzing dft_pred//3k2f_31c_sensitivity\3k2f_31c.csv
# Analyzing dft_pred//3k2f_31c_sensitivity\3k2f_31c_obsolete.csv
# No co2 density in dft_pred//3k2f_31c_sensitivity\3k2f_31c_obsolete.csv.
# Analyzing dft_pred//3k2f_31c_sensitivity\epsn_217-0.csv
# Analyzing dft_pred//3k2f_31c_sensitivity\epsn_224-0.csv
# Analyzing dft_pred//3k2f_31c_sensitivity\epsn_224-0~sigma_3-00.csv
# Analyzing dft_pred//3k2f_31c_sensitivity\epsn_224-0~sigma_3-07.csv
# Analyzing dft_pred//3k2f_31c_sensitivity\epsn_228-5~sigma_3-01~N_144-0.csv
# Analyzing dft_pred//3k2f_31c_sensitivity\epsn_232-8~sigma_3-22.csv
# Analyzing dft_pred//3k2f_31c_sensitivity\epsn_240-0.csv
# Analyzing dft_pred//3k2f_31c_sensitivity\epsn_240-0~sigma_3-07.csv
# Analyzing dft_pred//3k2f_31c_sensitivity\epsn_258-0~sigma_3-17.csv
# Analyzing dft_pred//3k2f_31c_sensitivity\N_117-0.csv
# Analyzing dft_pred//3k2f_31c_sensitivity\N_129-0.csv
# Analyzing dft_pred//3k2f_31c_sensitivity\sigma_2-86.csv
# Analyzing dft_pred//3k2f_31c_sensitivity\sigma_3-07.csv
# Analyzing dft_pred//3k2f_31c_sensitivity\sigma_3-16.csv
# Analyzing dft_pred//3k2f_31c_sensitivity\T_303-75.csv
# Analyzing dft_pred//3k2f_31c_sensitivity\T_304-75.csv
# Analyzing dft_pred//3k2f_60c_sensitivity\3k2f_60c_hip.csv
# No co2 density in dft_pred//3k2f_60c_sensitivity\3k2f_60c_hip.csv.
# Analyzing dft_pred//3k2f_60c_sensitivity\3k2f_60c_lop.csv
# No co2 density in dft_pred//3k2f_60c_sensitivity\3k2f_60c_lop.csv.
# Analyzing dft_pred//3k2f_60c_sensitivity\3k2f_60c_lop_obsolete.csv
# No co2 density in dft_pred//3k2f_60c_sensitivity\3k2f_60c_lop_obsolete.csv.
# Analyzing dft_pred//3k2f_60c_sensitivity\epsn_217-0.csv
# Analyzing dft_pred//3k2f_60c_sensitivity\epsn_224-0.csv
# Analyzing dft_pred//3k2f_60c_sensitivity\epsn_240-0.csv
# Analyzing dft_pred//3k2f_60c_sensitivity\epsn_258-0~sigma_3-17.csv
# Analyzing dft_pred//3k2f_60c_sensitivity\sigma_2-86.csv
# Analyzing dft_pred//3k2f_60c_sensitivity\sigma_3-17.csv
# Text(0, 0.5, 'Interfacial Tension [mN/m]')

# %% [markdown]
# ### Specific Volume

# %%
# folder of csv data files showing sensitivity of DFT predictions to PC-SAFT parameters
dft_sensitivity_folder = 'dft_pred//3k2f_31c_sensitivity//'

# loads dft predictions into a similarly structured dictionary
d_dft = dataproc.load_dft(dft_sensitivity_folder)

fig = plt.figure(figsize=(12, 4))
ax = fig.add_subplot(111)
# plots interfacial tension for 30 C
ax = plot.sensitivity_manual(d, d_dft, '3k2f_31c', 'spec_vol', 'epsn', epsn, data_folder, '', ['epsn_228-5~sigma_3-01~N_144-0'],
                                color='#1181B3', ms=10, m_ads='o', m_des='o', lw=4, ax=ax)
# folder of csv data files showing sensitivity of DFT predictions to PC-SAFT parameters
dft_sensitivity_folder = 'dft_pred//3k2f_60c_sensitivity//'

# loads dft predictions into a similarly structured dictionary
d_dft = dataproc.load_dft(dft_sensitivity_folder)

ax = plot.sensitivity_manual(d, d_dft, '3k2f_60c_lop', 'spec_vol', 'epsn', epsn, data_folder, '', [],
                                color='#B74A0D', ms=10, m_ads='o', m_des='o', lw=4, ax=ax)
ax.tick_params(labelsize=tk_fs)
ax.set_title('')
ax.set_xlabel(ax.xaxis.get_label().get_text(), fontsize=ax_fs)
ax.set_ylabel(ax.yaxis.get_label().get_text(), fontsize=ax_fs)
# Out:
# Analyzing dft_pred//3k2f_31c_sensitivity\3k2f_31c.csv
# Analyzing dft_pred//3k2f_31c_sensitivity\3k2f_31c_obsolete.csv
# No co2 density in dft_pred//3k2f_31c_sensitivity\3k2f_31c_obsolete.csv.
# Analyzing dft_pred//3k2f_31c_sensitivity\epsn_217-0.csv
# Analyzing dft_pred//3k2f_31c_sensitivity\epsn_224-0.csv
# Analyzing dft_pred//3k2f_31c_sensitivity\epsn_224-0~sigma_3-00.csv
# Analyzing dft_pred//3k2f_31c_sensitivity\epsn_224-0~sigma_3-07.csv
# Analyzing dft_pred//3k2f_31c_sensitivity\epsn_228-5~sigma_3-01~N_144-0.csv
# Analyzing dft_pred//3k2f_31c_sensitivity\epsn_232-8~sigma_3-22.csv
# Analyzing dft_pred//3k2f_31c_sensitivity\epsn_240-0.csv
# Analyzing dft_pred//3k2f_31c_sensitivity\epsn_240-0~sigma_3-07.csv
# Analyzing dft_pred//3k2f_31c_sensitivity\epsn_258-0~sigma_3-17.csv
# Analyzing dft_pred//3k2f_31c_sensitivity\N_117-0.csv
# Analyzing dft_pred//3k2f_31c_sensitivity\N_129-0.csv
# Analyzing dft_pred//3k2f_31c_sensitivity\sigma_2-86.csv
# Analyzing dft_pred//3k2f_31c_sensitivity\sigma_3-07.csv
# Analyzing dft_pred//3k2f_31c_sensitivity\sigma_3-16.csv
# Analyzing dft_pred//3k2f_31c_sensitivity\T_303-75.csv
# Analyzing dft_pred//3k2f_31c_sensitivity\T_304-75.csv
# Analyzing dft_pred//3k2f_60c_sensitivity\3k2f_60c_hip.csv
# No co2 density in dft_pred//3k2f_60c_sensitivity\3k2f_60c_hip.csv.
# Analyzing dft_pred//3k2f_60c_sensitivity\3k2f_60c_lop.csv
# No co2 density in dft_pred//3k2f_60c_sensitivity\3k2f_60c_lop.csv.
# Analyzing dft_pred//3k2f_60c_sensitivity\3k2f_60c_lop_obsolete.csv
# No co2 density in dft_pred//3k2f_60c_sensitivity\3k2f_60c_lop_obsolete.csv.
# Analyzing dft_pred//3k2f_60c_sensitivity\epsn_217-0.csv
# Analyzing dft_pred//3k2f_60c_sensitivity\epsn_224-0.csv
# Analyzing dft_pred//3k2f_60c_sensitivity\epsn_240-0.csv
# Analyzing dft_pred//3k2f_60c_sensitivity\epsn_258-0~sigma_3-17.csv
# Analyzing dft_pred//3k2f_60c_sensitivity\sigma_2-86.csv
# Analyzing dft_pred//3k2f_60c_sensitivity\sigma_3-17.csv
# Text(0, 0.5, 'Specific Volume [mL/g]')

# %% [markdown]
# Repeat plots for 60 C.
