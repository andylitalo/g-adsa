# %% [markdown]
# # Guessing the Parameters for a PC-SAFT Model of 1k3f Polyol

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import dataproc
import plot

from importlib import reload

# System parameters
# molecular weight of CO2
mw_co2 = 44.01
# conversion of m3 per mL
m3_per_mL = 1E-6
# Save plots?
save_plots = True
# file path to saved data
data_folder = '../g-adsa_results/'
# csv data files
csv_file_list = ['1k3f_30c', '1k3f_60c']

# %% [markdown]
# Loads data into dictionary.

# %%
d = dataproc.load_proc_data(csv_file_list, data_folder)

# %% [markdown]
# Compare results of prediction with guessed PC-SAFT parameters to actual data.

# %%
reload(dataproc)
reload(plot)

# folder of csv data files showing sensitivity of DFT predictions to PC-SAFT parameters
dft_sensitivity_folder = 'dft_pred//1k3f_30c_sensitivity//'

# loads dft predictions into a similarly structured dictionary
d_dft = dataproc.load_dft(dft_sensitivity_folder)

# plots interfacial tension for 30 C
_ = plot.sensitivity_manual(d, d_dft, '1k3f_30c', 'if_tension', 'epsn', 229.3, data_folder, 
                            '', ['epsn_233-0~sigma_3-01'])

# plots solubility for 30 C
_ = plot.sensitivity_manual(d, d_dft, '1k3f_30c', 'solub', 'epsn', 229.3, data_folder, 
                            '', ['epsn_233-0~sigma_3-01'])

# %% [markdown]
# Repeat plots for 60 C.

# %%
# folder of csv data files showing sensitivity of DFT predictions to PC-SAFT parameters
dft_sensitivity_folder = 'dft_pred//1k3f_60c_sensitivity//'

# loads dft predictions into a similarly structured dictionary
d_dft = dataproc.load_dft(dft_sensitivity_folder)

# plots interfacial tension for 60 C
_ = plot.sensitivity_manual(d, d_dft, '1k3f_60c', 'if_tension', 'epsn', 229.3, data_folder, 
                            '', ['epsn_233-0~sigma_3-01'])

# plots solubility for 60 C
_ = plot.sensitivity_manual(d, d_dft, '1k3f_60c', 'solub', 'epsn', 229.3, data_folder, 
                            '', ['epsn_233-0~sigma_3-01'])

# %% [markdown]
# ### Specific Volume

# %%
# # plots result of varying sigma
# _ = plot.sensitivity_manual(d, d_dft, '3k2f_31c', 'spec_vol', 'sigma', 3.01, data_folder, 
#                             '3k2f_31c_if_tension_dft_vary_sigma_multi.pdf', 
#                             ['sigma_2-86', 'sigma_3-07', 'sigma_3-16', 'epsn_240-0~sigma_3-07',
#                             'epsn_258-0~sigma_3-17'])
